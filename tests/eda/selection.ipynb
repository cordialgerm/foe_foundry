# %% [markdown]
# ## Spy

# %%
from tests.eda.simulate import plot_simulation
from foe_foundry.creatures.spy import generate_spy, SpyMasterVariant
from foe_foundry.creatures.species import HumanSpecies


def make_spy(rng):
    spy = generate_spy("Spy Master", cr=10, variant=SpyMasterVariant, species=HumanSpecies, rng=rng)
    return spy

plot_simulation(make_spy, 500)
# Out:
# /Users/evanrash/code/foe_foundry/tests/eda/simulate.py:51: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90)
# /Users/evanrash/code/foe_foundry/tests/eda/simulate.py:60: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90)

# %% [markdown]
# ## Bandit

# %%
from tests.eda.simulate import plot_simulation
from foe_foundry.creatures.bandit import generate_bandit, BanditCaptainVariant
from foe_foundry.creatures.species import HumanSpecies


def make_bandit(rng):
    spy = generate_bandit("Bandit Crime Lord", cr=11, variant=BanditCaptainVariant, species=HumanSpecies, rng=rng)
    return spy

plot_simulation(make_bandit, 500)
# Out:
# /Users/evanrash/code/foe_foundry/tests/eda/simulate.py:51: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90)
# /Users/evanrash/code/foe_foundry/tests/eda/simulate.py:60: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90)

# %% [markdown]
# ## Thugs

# %%
from tests.eda.simulate import plot_simulation
from foe_foundry.creatures.tough import generate_tough, BossVariant
from foe_foundry.creatures.species import HumanSpecies


def make_tough(rng):
    spy = generate_tough("Thug Legend", cr=8, variant=BossVariant, species=HumanSpecies, rng=rng)
    return spy

plot_simulation(make_tough, 500)
# Out:
# /Users/evanrash/code/foe_foundry/tests/eda/simulate.py:51: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90)
# /Users/evanrash/code/foe_foundry/tests/eda/simulate.py:60: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90)

# %% [markdown]
# ## Assassin

# %%
from tests.eda.simulate import plot_simulation
from foe_foundry.creatures.assassin import generate_assassin, AssassinVariant
from foe_foundry.creatures.species import HumanSpecies


def make_assassin(rng):
    return generate_assassin("Assassin Legend", cr=15, variant=AssassinVariant, species=HumanSpecies, rng=rng)

plot_simulation(make_assassin, 500)
# Out:
# /Users/evanrash/code/foe_foundry/tests/eda/simulate.py:51: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90)
# /Users/evanrash/code/foe_foundry/tests/eda/simulate.py:60: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90)

# %% [markdown]
# ## Cultist

# %%
from tests.eda.simulate import plot_simulation
from foe_foundry.creatures.cultist import generate_cultist, CultistVariant

def make_cultist(rng):
    cultist = generate_cultist("Cultist Exarch", cr=18, variant=CultistVariant, rng=rng)
    return cultist

plot_simulation(make_cultist, 500)
# Out:
# /Users/evanrash/code/foe_foundry/tests/eda/simulate.py:51: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90)
# /Users/evanrash/code/foe_foundry/tests/eda/simulate.py:60: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90)

# %% [markdown]
# ## Skeletons

# %%
from tests.eda.simulate import plot_simulation
from foe_foundry.creatures.skeleton import generate_skeleton, FreezingSkeletonVariant, BurningSkeletonVariant


def make_freezing_skeleton(rng):
    return generate_skeleton("Freezing Skeleton", cr=6, variant=FreezingSkeletonVariant, rng=rng)

def make_burning_skeleton(rng):
    return generate_skeleton("Burning Skeleton", cr=6, variant=BurningSkeletonVariant, rng=rng)

plot_simulation(make_freezing_skeleton, 500)
plot_simulation(make_burning_skeleton, 500)
# Out:
# /Users/evanrash/code/foe_foundry/tests/eda/simulate.py:51: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90)
# /Users/evanrash/code/foe_foundry/tests/eda/simulate.py:60: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90)
# /Users/evanrash/code/foe_foundry/tests/eda/simulate.py:51: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90)
# /Users/evanrash/code/foe_foundry/tests/eda/simulate.py:60: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90)

# %% [markdown]
# ## Berserker

# %%
from tests.eda.simulate import plot_simulation
from foe_foundry.creatures.berserker import generate_berserker, CommanderVariant
from foe_foundry.creatures.species import HumanSpecies


def make_berserker(rng):
    return generate_berserker("Berserker Legend", cr=14, variant=CommanderVariant, species=HumanSpecies, rng=rng)

plot_simulation(make_berserker, 500)
# Out:
# /Users/evanrash/code/foe_foundry/tests/eda/simulate.py:51: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90)
# /Users/evanrash/code/foe_foundry/tests/eda/simulate.py:60: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90)

# %% [markdown]
# ## Zombie

# %%
from tests.eda.simulate import plot_simulation
from foe_foundry.creatures.zombie import generate_zombie, ZombieOgreVariant


def make_zombie(rng):
    spy = generate_zombie("Zombie Titan", cr=16, variant=ZombieOgreVariant, rng=rng)
    return spy

plot_simulation(make_zombie, 500)
# Out:
# /Users/evanrash/code/foe_foundry/tests/eda/simulate.py:51: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90)
# /Users/evanrash/code/foe_foundry/tests/eda/simulate.py:60: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90)
