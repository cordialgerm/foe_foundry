# %%
from tests.eda.simulate import plot_simulation
from foe_foundry.creatures.guard import GuardTemplate, GuardVariant, CommanderVariant


plot_simulation(template=GuardTemplate, variant=GuardVariant, n=100, temperature=1.0, full_plot=False)
plot_simulation(template=GuardTemplate, variant=CommanderVariant, n=100, temperature=1.0, full_plot=False)
# Out:
# /Users/evanrash/code/foe_foundry/tests/eda/simulate.py:71: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90)
# /Users/evanrash/code/foe_foundry/tests/eda/simulate.py:71: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90)
