# %%
from tests.eda.simulate import plot_simulation
from foe_foundry.creatures.knight import KnightTemplate, KnightVariant


for suggested_cr in KnightVariant.suggested_crs:
    plot_simulation(template=KnightTemplate, variant=KnightVariant, suggested_cr=suggested_cr, n=100, temperature=1.0, full_plot=False)
# Out:
# /Users/evanrash/code/foe_foundry/tests/eda/simulate.py:78: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90)
# /Users/evanrash/code/foe_foundry/tests/eda/simulate.py:78: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90)
# /Users/evanrash/code/foe_foundry/tests/eda/simulate.py:78: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90)
# /Users/evanrash/code/foe_foundry/tests/eda/simulate.py:78: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90)
