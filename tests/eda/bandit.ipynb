# %%
from tests.eda.simulate import plot_simulation
from foe_foundry.creatures.bandit import BanditTemplate, BanditCaptainVariant


plot_simulation(template=BanditTemplate, variant=BanditCaptainVariant, n=100, temperature=0.0)
plot_simulation(template=BanditTemplate, variant=BanditCaptainVariant, n=100, temperature=0.5)
plot_simulation(template=BanditTemplate, variant=BanditCaptainVariant, n=100, temperature=1.0)
plot_simulation(template=BanditTemplate, variant=BanditCaptainVariant, n=100, temperature=2.0)
plot_simulation(template=BanditTemplate, variant=BanditCaptainVariant, n=100, temperature=3.0)
# Out:
# /Users/evanrash/code/foe_foundry/tests/eda/simulate.py:71: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90)
# /Users/evanrash/code/foe_foundry/tests/eda/simulate.py:71: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90)
# /Users/evanrash/code/foe_foundry/tests/eda/simulate.py:71: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90)
# /Users/evanrash/code/foe_foundry/tests/eda/simulate.py:71: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90)
# ...
