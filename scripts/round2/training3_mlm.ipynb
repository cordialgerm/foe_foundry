# %%
from transformers import AutoTokenizer, AutoModelForMaskedLM, Trainer, TrainingArguments, EarlyStoppingCallback, DataCollatorForLanguageModeling
from foe_foundry_nl.data.training import load_mlm_dataset
from pathlib import Path
import torch
import math
import numpy as np
from nltk.corpus import wordnet

# %%
# model = "sentence-transformers/msmarco-MiniLM-L12-cos-v5"
model_name = "sentence-transformers/all-MiniLM-L12-v2"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForMaskedLM.from_pretrained(model_name)

dataset = load_mlm_dataset()
print(f"Training: {len(dataset['train'])}")
print(f"Eval: {len(dataset['eval'])}")
print(f"Test: {len(dataset['test'])}")
# Out:
# Some weights of BertForMaskedLM were not initialized from the model checkpoint at sentence-transformers/all-MiniLM-L12-v2 and are newly initialized: ['cls.predictions.bias', 'cls.predictions.decoder.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Training: 3485
# Eval: 463
# Test: 487

# %%
# tokenize data
def tokenize_function(examples):
    return tokenizer(
        examples["text"], padding="max_length", truncation=True, max_length=512
    )

tokenized_dataset = dataset.map(
    tokenize_function, batched=True, remove_columns=["text"]
)

# Set up Trainer
data_collator = DataCollatorForLanguageModeling(
    tokenizer=tokenizer, mlm=True, mlm_probability=0.15
)


n_train = len(dataset["train"])
num_train_epochs = 5
train_batch_size = 32
total_steps = (n_train // train_batch_size) * num_train_epochs
warmup_steps = total_steps // 10


output_dir = Path.cwd().parent / "models" / "minilm-finetuned"
output_dir.mkdir(exist_ok=True)
trainer = Trainer(
    model=model,
    args=TrainingArguments(
        output_dir=str(output_dir),
        eval_strategy="epoch",
        save_strategy="epoch",
        logging_dir="./logs",
        logging_strategy="steps",
        logging_steps=10,
        num_train_epochs=num_train_epochs,
        per_device_train_batch_size=train_batch_size,
        per_device_eval_batch_size=2 * train_batch_size,
        learning_rate=5e-5,
        lr_scheduler_type="cosine",
        warmup_steps=warmup_steps,
        load_best_model_at_end=True,
    ),
    train_dataset=tokenized_dataset["train"],  # type: ignore
    eval_dataset=tokenized_dataset["test"],  # type: ignore
    data_collator=data_collator,
    callbacks=[EarlyStoppingCallback(early_stopping_patience=3)],
)

trainer.train(resume_from_checkpoint=True)
model.save_pretrained(output_dir)
tokenizer.save_pretrained(output_dir)
# Out:
# Map:   0%|          | 0/3485 [00:00<?, ? examples/s]
# Map:   0%|          | 0/463 [00:00<?, ? examples/s]
# Map:   0%|          | 0/487 [00:00<?, ? examples/s]
# There were missing keys in the checkpoint model loaded: ['cls.predictions.decoder.weight', 'cls.predictions.decoder.bias'].
# c:\code\foe_foundry\.venv\lib\site-packages\transformers\trainer.py:3262: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   torch.load(os.path.join(checkpoint, OPTIMIZER_NAME), map_location=map_location)
#   0%|          | 0/545 [00:00<?, ?it/s]
# There were missing keys in the checkpoint model loaded: ['cls.predictions.decoder.weight', 'cls.predictions.decoder.bias'].
# {'train_runtime': 0.1108, 'train_samples_per_second': 157248.385, 'train_steps_per_second': 4918.242, 'train_loss': 0.0, 'epoch': 5.0}
# ('c:\\code\\foe_foundry\\models\\minilm-finetuned\\tokenizer_config.json',
#  'c:\\code\\foe_foundry\\models\\minilm-finetuned\\special_tokens_map.json',
#  'c:\\code\\foe_foundry\\models\\minilm-finetuned\\vocab.txt',
#  'c:\\code\\foe_foundry\\models\\minilm-finetuned\\added_tokens.json',
#  'c:\\code\\foe_foundry\\models\\minilm-finetuned\\tokenizer.json')

# %%
fine_tuned_dir = Path.cwd().parent / "models" / "minilm-finetuned"

baseline_model_name = "bert-base-uncased"
tokenizer = AutoTokenizer.from_pretrained(baseline_model_name)
baseline_model = AutoModelForMaskedLM.from_pretrained(baseline_model_name)
finetuned_model = AutoModelForMaskedLM.from_pretrained(fine_tuned_dir)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
baseline_model.to(device)
finetuned_model.to(device)

def predict_mask(sentence: str, model: AutoModelForMaskedLM) -> str:
    inputs = tokenizer(sentence, return_tensors="pt").to(device)  # type: ignore
    with torch.no_grad():
        outputs = model(**inputs)  # type: ignore
        logits = outputs.logits

    # Find the index of the [MASK] token
    mask_token_index = (inputs["input_ids"] == tokenizer.mask_token_id).nonzero(as_tuple=True)[1]  # type: ignore

    # Get the top predicted token for the [MASK]
    mask_token_logits = logits[0, mask_token_index, :]
    top_token = torch.argmax(mask_token_logits, dim=1)
    predicted_token = tokenizer.decode(top_token)  # type: ignore

    return predicted_token

def calculate_perplexity(model, sentence: str):
    # Tokenize and prepare input
    inputs = tokenizer(sentence, return_tensors="pt").to(device)
    inputs["labels"]  = inputs["input_ids"].clone()  # type: ignore
    with torch.no_grad():
        outputs = model(**inputs)
        logits = outputs.logits

    # Identify the position of the [MASK] token
    mask_token_index = (inputs["input_ids"] == tokenizer.mask_token_id).nonzero(as_tuple=True)[1]
    mask_logits = logits[0, mask_token_index, :]

    # Calculate softmax probabilities for the masked position
    log_prob = torch.log_softmax(mask_logits, dim=-1)

    # Get perplexity from the log-probability of the correct token
    correct_token_id = inputs["labels"][0, mask_token_index]
    token_log_prob = log_prob[0, correct_token_id].item()
    perplexity = math.exp(-token_log_prob)

    return perplexity



# Evaluation Sentences
eval_sentences = [
    # Monster category (50 sentences)
    (1, "Monster", "The [MASK] prowled through the forest under the cover of darkness.", "beast"),
    (2, "Monster", "With every swing, the giant's [MASK] echoed across the battlefield.", "club"),
    (3, "Monster", "The wyvern's tail lashed out, coated in deadly [MASK].", "venom"),
    (4, "Monster", "A [MASK] of goblins stormed the village, setting fire to everything in sight.", "horde"),
    (5, "Monster", "Legends tell of a creature that [MASK] fire from its maw.", "breathes"),
    (6, "Monster", "The ancient red dragon's scales shimmered with a [MASK] glow.", "fiery"),
    (7, "Monster", "Its eyes gleamed with [MASK], promising destruction.", "malice"),
    (8, "Monster", "The ogre charged forward with a deafening [MASK].", "roar"),
    (9, "Monster", "A cloud of chill [MASK] surrounded the banshee as it hovered above the ground.", "mist"),
    (10, "Monster", "The troll's regeneration ability allows it to heal unless exposed to [MASK].", "fire"),
    (11, "Monster", "An aura of [MASK] surrounds the demon, weakening all within reach.", "fear"),
    (12, "Monster", "The hydra grows two heads for every [MASK] one.", "severed"),
    (13, "Monster", "A dire wolf's [MASK] is powerful enough to knock down a grown man.", "bite"),
    (14, "Monster", "The undead knight's blade was cursed with [MASK] magic.", "necrotic"),
    (15, "Monster", "A chimera's three heads grant it a [MASK] of attacks.", "variety"),
    (16, "Monster", "The hidden [MASK] lurked just beyond the flickering torchlight.", "shadow"),
    (17, "Monster", "The behir's lightning breath deals [MASK] damage in a straight line.", "electric"),
    (18, "Monster", "The gelatinous cube absorbs anything that it [MASK].", "touches"),
    (19, "Monster", "A vampire cannot enter a home without an invitation from a [MASK].", "mortal"),
    (20, "Monster", "The harpy's song draws travelers into deadly [MASK].", "traps"),
    (21, "Monster", "When the basilisk's gaze falls upon its victim, they turn to [MASK].", "stone"),
    (22, "Monster", "A lich's phylactery contains its [MASK].", "soul"),
    (23, "Monster", "The dragon turtle can breathe underwater and expel a cone of [MASK].", "steam"),
    (24, "Monster", "The griffon can serve as a loyal [MASK] for a Paladin.", "steed"),
    (25, "Monster", "A kobold's trap is more dangerous than the [MASK] itself.", "creature"),
    (26, "Monster", "The minotaur guards the [MASK] deep within the labyrinth.", "treasure"),
    (27, "Monster", "A werewolf transforms under the [MASK] of a full moon.", "light"),
    (28, "Monster", "The cyclops wields a tree as if it were a [MASK].", "club"),
    (29, "Monster", "A manticore can fire [MASK] from its spiked tail.", "spines"),
    (30, "Monster", "The massive eagle-like [MASK] spreads its wings and takes to the sky.", "roc"),
    (31, "Monster", "The salamander thrives in the [MASK] of active volcanoes.", "heat"),
    (32, "Monster", "The banshee's wail can [MASK] the souls of the living.", "shatter"),
    (33, "Monster", "A gelatinous cube's form is nearly [MASK].", "invisible"),
    (34, "Monster", "A succubus charms its victims with [MASK].", "beauty"),
    (35, "Monster", "The golem follows the commands of its [MASK] without question.", "creator"),
    (36, "Monster", "A mimic disguises itself as mundane [MASK] to ambush prey.", "objects"),
    (37, "Monster", "The mind flayer consumes the [MASK] of its victims.", "brains"),
    (38, "Monster", "The kraken's tentacles can drag entire [MASK] into the sea.", "ships"),
    (39, "Monster", "A hellhound's breath smells of [MASK] sulfur.", "burning"),
    (40, "Monster", "The frost giant's ax is enchanted with [MASK] magic.", "ice"),
    (41, "Monster", "A night hag can invade dreams and spread [MASK].", "nightmares"),
    (42, "Monster", "The beholder's central eye projects an anti-[MASK] cone.", "magic"),
    (43, "Monster", "The basilisk's venom causes [MASK] to spread through the veins.", "paralysis"),
    (44, "Monster", "The dracolich is an [MASK] dragon and a powerful spellcaster.", "undead"),
    (45, "Monster", "The djinn can grant wishes, but always with a [MASK].", "price"),
    (46, "Monster", "The owlbear's screech is enough to scare off most [MASK].", "predators"),
    (47, "Monster", "A fire elemental engulfs everything in [MASK].", "flames"),
    (48, "Monster", "The ghost is trapped in the mortal plane by unfinished [MASK].", "business"),
    (49, "Monster", "A ghast's stench is so foul it causes those nearby to [MASK].", "retreat"),
    (50, "Monster", "The hydra retreats only when all of its heads are [MASK].", "destroyed"),

    # Spells category (10 sentences)
    (51, "Spells", "Casting [MASK] allows the wizard to hover for a short duration.", "levitate"),
    (52, "Spells", "The sorcerer can summon a [MASK] to fight by their side.", "familiar"),
    (53, "Spells", "The cleric's healing spell can restore [MASK] to the injured.", "life"),
    (54, "Spells", "The mage conjures an [MASK] of a roaring demon to deceive enemies.", "illusion"),
    (55, "Spells", "The paladin casts [MASK] of faith to protect their allies from harm.", "shield"),
    (56, "Spells", "A druid can speak with [MASK] using a simple incantation.", "animals"),
    (57, "Spells", "The bard's song inspires [MASK] in their companions.", "courage"),
    (58, "Spells", "With a flick of her wrist, she cast the [MASK] spell as a beam of red light streaks forth.", "fireball"),
    (59, "Spells", "The necromancer raises a [MASK] with a word of power.", "skeleton"),
    (60, "Spells", "The spell of invisibility renders the caster [MASK].", "undetectable"),

    # Rules category (10 sentences)
    (61, "Rules", "Casting a spell is an example of an [MASK].", "action"),
    (62, "Rules", "Rolling a [MASK] causes an automatic success.", "natural 20"),
    (63, "Rules", "Players can take an [MASK], bonus action, and a reaction on their turn", "action"),
    (64, "Rules", "Critical hits deal [MASK] the normal damage.", "double"),
    (65, "Rules", "A failed [MASK] throw can result in the paralyzed status.", "saving"),
    (66, "Rules", "An attack of opportunity occurs when an enemy [MASK].", "retreats"),
    (67, "Rules", "Spellcasters must maintain [MASK] to keep concentration spells active.", "focus"),
    (68, "Rules", "A short rest allows players to recover [MASK].", "hit points"),
    (69, "Rules", "During combat, players act in order of their [MASK].", "initiative"),
    (70, "Rules", "The DM can award [MASK] for excellent roleplaying.", "inspiration")
]

def get_synonyms(word):
    """Retrieve synonyms for a word from WordNet."""
    synonyms = {word}
    for syn in wordnet.synsets(word):
        for lemma in syn.lemmas():
            synonyms.add(lemma.name().lower())
    return synonyms

def is_correct_prediction(predicted, expected):
    """Check if the prediction matches the expected word or a synonym."""
    predicted = predicted.strip().lower()
    expected_synonyms = get_synonyms(expected)
    return predicted in expected_synonyms



def evaluate_model(model):
    correct_predictions = 0
    perplexities = []

    print(f"\nEvaluating Model: {model.config._name_or_path}\n")
    for (idx, category, sentence, expected) in eval_sentences:
        predicted = predict_mask(sentence, model)
        is_correct = is_correct_prediction(predicted, expected)
        perplexity = calculate_perplexity(model, sentence)
        perplexities.append(perplexity)
        correct_predictions += int(is_correct)

        print(f"ID: {idx} | Category: {category}")
        print(f"  Sentence: {sentence}")
        print(f"  Predicted: {predicted} | Expected: {expected} | Correct: {is_correct}\n")
        print(f"  Perplexity: {perplexity:.2f}\n")


    accuracy = correct_predictions / len(eval_sentences) * 100
    avg_perplexity = np.mean(perplexities)
    print(f"Accuracy: {accuracy:.2f}% ({correct_predictions}/{len(eval_sentences)})")
    print(f"Average Perplexity: {avg_perplexity:.2f}")


print("EVALUATION\n")
print("BASELINE:")
evaluate_model(baseline_model)
print("FINE TUNED:")
evaluate_model(finetuned_model)
# Out:
# BertForMaskedLM has generative capabilities, as `prepare_inputs_for_generation` is explicitly overwritten. However, it doesn't directly inherit from `GenerationMixin`. From 👉v4.50👈 onwards, `PreTrainedModel` will NOT inherit from `GenerationMixin`, and this model will lose the ability to call `generate` and other related functions.
#   - If you're using `trust_remote_code=True`, you can get rid of this warning by loading the model with an auto class. See https://huggingface.co/docs/transformers/en/model_doc/auto#auto-classes
#   - If you are the owner of the model architecture code, please modify your model class such that it inherits from `GenerationMixin` (after `PreTrainedModel`, otherwise you'll get an exception).
#   - If you are not the owner of the model architecture class, please contact the model code owner to update it.
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# EVALUATION
#
# BASELINE:
#
# Evaluating Model: bert-base-uncased
# c:\code\foe_foundry\.venv\lib\site-packages\transformers\models\bert\modeling_bert.py:440: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:555.)
#   attn_output = torch.nn.functional.scaled_dot_product_attention(
# ID: 1 | Category: Monster
#   Sentence: The [MASK] prowled through the forest under the cover of darkness.
#   Predicted: creature | Expected: beast | Correct: True
#
#   Perplexity: 32256937.62
#
# ID: 2 | Category: Monster
#   Sentence: With every swing, the giant's [MASK] echoed across the battlefield.
#   Predicted: scream | Expected: club | Correct: False
#
#   Perplexity: 451404147.98
#
# ID: 3 | Category: Monster
#   Sentence: The wyvern's tail lashed out, coated in deadly [MASK].
#   Predicted: venom | Expected: venom | Correct: True
#
#   Perplexity: 91465673.26
#
# ID: 4 | Category: Monster
#   Sentence: A [MASK] of goblins stormed the village, setting fire to everything in sight.
#   Predicted: mob | Expected: horde | Correct: False
#
#   Perplexity: 83590448.52
#
# ID: 5 | Category: Monster
#   Sentence: Legends tell of a creature that [MASK] fire from its maw.
#   Predicted: drew | Expected: breathes | Correct: False
#
#   Perplexity: 742565048.87
#
# ID: 6 | Category: Monster
#   Sentence: The ancient red dragon's scales shimmered with a [MASK] glow.
#   Predicted: golden | Expected: fiery | Correct: False
#
#   Perplexity: 454811810.07
#
# ID: 7 | Category: Monster
#   Sentence: Its eyes gleamed with [MASK], promising destruction.
#   Predicted: fear | Expected: malice | Correct: False
#
#   Perplexity: 67219742.82
#
# ID: 8 | Category: Monster
#   Sentence: The ogre charged forward with a deafening [MASK].
#   Predicted: roar | Expected: roar | Correct: True
#
#   Perplexity: 341350488.83
#
# ID: 9 | Category: Monster
#   Sentence: A cloud of chill [MASK] surrounded the banshee as it hovered above the ground.
#   Predicted: air | Expected: mist | Correct: False
#
#   Perplexity: 556944244.23
#
# ID: 10 | Category: Monster
#   Sentence: The troll's regeneration ability allows it to heal unless exposed to [MASK].
#   Predicted: sunlight | Expected: fire | Correct: False
#
#   Perplexity: 45529068.21
#
# ID: 11 | Category: Monster
#   Sentence: An aura of [MASK] surrounds the demon, weakening all within reach.
#   Predicted: power | Expected: fear | Correct: False
#
#   Perplexity: 23379341.71
#
# ID: 12 | Category: Monster
#   Sentence: The hydra grows two heads for every [MASK] one.
#   Predicted: other | Expected: severed | Correct: False
#
#   Perplexity: 65363205.23
#
# ID: 13 | Category: Monster
#   Sentence: A dire wolf's [MASK] is powerful enough to knock down a grown man.
#   Predicted: strength | Expected: bite | Correct: False
#
#   Perplexity: 35167712.52
#
# ID: 14 | Category: Monster
#   Sentence: The undead knight's blade was cursed with [MASK] magic.
#   Predicted: black | Expected: necrotic | Correct: False
#
#   Perplexity: 81036877.47
#
# ID: 15 | Category: Monster
#   Sentence: A chimera's three heads grant it a [MASK] of attacks.
#   Predicted: range | Expected: variety | Correct: False
#
#   Perplexity: 38392885.27
#
# ID: 16 | Category: Monster
#   Sentence: The hidden [MASK] lurked just beyond the flickering torchlight.
#   Predicted: treasure | Expected: shadow | Correct: False
#
#   Perplexity: 13021575.91
#
# ID: 17 | Category: Monster
#   Sentence: The behir's lightning breath deals [MASK] damage in a straight line.
#   Predicted: the | Expected: electric | Correct: False
#
#   Perplexity: 2367473.31
#
# ID: 18 | Category: Monster
#   Sentence: The gelatinous cube absorbs anything that it [MASK].
#   Predicted: touches | Expected: touches | Correct: True
#
#   Perplexity: 3539081354.81
#
# ID: 19 | Category: Monster
#   Sentence: A vampire cannot enter a home without an invitation from a [MASK].
#   Predicted: vampire | Expected: mortal | Correct: False
#
#   Perplexity: 62886761.92
#
# ID: 20 | Category: Monster
#   Sentence: The harpy's song draws travelers into deadly [MASK].
#   Predicted: danger | Expected: traps | Correct: False
#
#   Perplexity: 165731643.39
#
# ID: 21 | Category: Monster
#   Sentence: When the basilisk's gaze falls upon its victim, they turn to [MASK].
#   Predicted: look | Expected: stone | Correct: False
#
#   Perplexity: 2348576.85
#
# ID: 22 | Category: Monster
#   Sentence: A lich's phylactery contains its [MASK].
#   Predicted: contents | Expected: soul | Correct: False
#
#   Perplexity: 3498765.27
#
# ID: 23 | Category: Monster
#   Sentence: The dragon turtle can breathe underwater and expel a cone of [MASK].
#   Predicted: water | Expected: steam | Correct: False
#
#   Perplexity: 20571407.60
#
# ID: 24 | Category: Monster
#   Sentence: The griffon can serve as a loyal [MASK] for a Paladin.
#   Predicted: companion | Expected: steed | Correct: False
#
#   Perplexity: 15591148.35
#
# ID: 25 | Category: Monster
#   Sentence: A kobold's trap is more dangerous than the [MASK] itself.
#   Predicted: trap | Expected: creature | Correct: False
#
#   Perplexity: 32740734.18
#
# ID: 26 | Category: Monster
#   Sentence: The minotaur guards the [MASK] deep within the labyrinth.
#   Predicted: entrance | Expected: treasure | Correct: False
#
#   Perplexity: 14475780.76
#
# ID: 27 | Category: Monster
#   Sentence: A werewolf transforms under the [MASK] of a full moon.
#   Predicted: light | Expected: light | Correct: True
#
#   Perplexity: 22358085785.26
#
# ID: 28 | Category: Monster
#   Sentence: The cyclops wields a tree as if it were a [MASK].
#   Predicted: sword | Expected: club | Correct: False
#
#   Perplexity: 58051913.05
#
# ID: 29 | Category: Monster
#   Sentence: A manticore can fire [MASK] from its spiked tail.
#   Predicted: arrows | Expected: spines | Correct: False
#
#   Perplexity: 88177363.63
#
# ID: 30 | Category: Monster
#   Sentence: The massive eagle-like [MASK] spreads its wings and takes to the sky.
#   Predicted: creature | Expected: roc | Correct: False
#
#   Perplexity: 14028133.31
#
# ID: 31 | Category: Monster
#   Sentence: The salamander thrives in the [MASK] of active volcanoes.
#   Predicted: vicinity | Expected: heat | Correct: False
#
#   Perplexity: 55324994.89
#
# ID: 32 | Category: Monster
#   Sentence: The banshee's wail can [MASK] the souls of the living.
#   Predicted: destroy | Expected: shatter | Correct: False
#
#   Perplexity: 10847754.01
#
# ID: 33 | Category: Monster
#   Sentence: A gelatinous cube's form is nearly [MASK].
#   Predicted: spherical | Expected: invisible | Correct: False
#
#   Perplexity: 25488298.21
#
# ID: 34 | Category: Monster
#   Sentence: A succubus charms its victims with [MASK].
#   Predicted: fire | Expected: beauty | Correct: False
#
#   Perplexity: 14723189.28
#
# ID: 35 | Category: Monster
#   Sentence: The golem follows the commands of its [MASK] without question.
#   Predicted: master | Expected: creator | Correct: False
#
#   Perplexity: 45355892.47
#
# ID: 36 | Category: Monster
#   Sentence: A mimic disguises itself as mundane [MASK] to ambush prey.
#   Predicted: ##s | Expected: objects | Correct: False
#
#   Perplexity: 2655812.32
#
# ID: 37 | Category: Monster
#   Sentence: The mind flayer consumes the [MASK] of its victims.
#   Predicted: minds | Expected: brains | Correct: False
#
#   Perplexity: 33808913.76
#
# ID: 38 | Category: Monster
#   Sentence: The kraken's tentacles can drag entire [MASK] into the sea.
#   Predicted: species | Expected: ships | Correct: False
#
#   Perplexity: 8755154.74
#
# ID: 39 | Category: Monster
#   Sentence: A hellhound's breath smells of [MASK] sulfur.
#   Predicted: burning | Expected: burning | Correct: True
#
#   Perplexity: 8020447.74
#
# ID: 40 | Category: Monster
#   Sentence: The frost giant's ax is enchanted with [MASK] magic.
#   Predicted: frost | Expected: ice | Correct: True
#
#   Perplexity: 26922856.71
#
# ID: 41 | Category: Monster
#   Sentence: A night hag can invade dreams and spread [MASK].
#   Predicted: them | Expected: nightmares | Correct: False
#
#   Perplexity: 12346888.46
#
# ID: 42 | Category: Monster
#   Sentence: The beholder's central eye projects an anti-[MASK] cone.
#   Predicted: clockwise | Expected: magic | Correct: False
#
#   Perplexity: 37969268.77
#
# ID: 43 | Category: Monster
#   Sentence: The basilisk's venom causes [MASK] to spread through the veins.
#   Predicted: it | Expected: paralysis | Correct: False
#
#   Perplexity: 18787656.30
#
# ID: 44 | Category: Monster
#   Sentence: The dracolich is an [MASK] dragon and a powerful spellcaster.
#   Predicted: evil | Expected: undead | Correct: False
#
#   Perplexity: 16545298.63
#
# ID: 45 | Category: Monster
#   Sentence: The djinn can grant wishes, but always with a [MASK].
#   Predicted: curse | Expected: price | Correct: False
#
#   Perplexity: 20967941.81
#
# ID: 46 | Category: Monster
#   Sentence: The owlbear's screech is enough to scare off most [MASK].
#   Predicted: birds | Expected: predators | Correct: False
#
#   Perplexity: 39425278.51
#
# ID: 47 | Category: Monster
#   Sentence: A fire elemental engulfs everything in [MASK].
#   Predicted: sight | Expected: flames | Correct: False
#
#   Perplexity: 71930664.96
#
# ID: 48 | Category: Monster
#   Sentence: The ghost is trapped in the mortal plane by unfinished [MASK].
#   Predicted: business | Expected: business | Correct: True
#
#   Perplexity: 61224938.42
#
# ID: 49 | Category: Monster
#   Sentence: A ghast's stench is so foul it causes those nearby to [MASK].
#   Predicted: gag | Expected: retreat | Correct: False
#
#   Perplexity: 33905198.31
#
# ID: 50 | Category: Monster
#   Sentence: The hydra retreats only when all of its heads are [MASK].
#   Predicted: severed | Expected: destroyed | Correct: False
#
#   Perplexity: 2649533.39
#
# ID: 51 | Category: Spells
#   Sentence: Casting [MASK] allows the wizard to hover for a short duration.
#   Predicted: spells | Expected: levitate | Correct: False
#
#   Perplexity: 2057547.82
#
# ID: 52 | Category: Spells
#   Sentence: The sorcerer can summon a [MASK] to fight by their side.
#   Predicted: dragon | Expected: familiar | Correct: False
#
#   Perplexity: 20016338.09
#
# ID: 53 | Category: Spells
#   Sentence: The cleric's healing spell can restore [MASK] to the injured.
#   Predicted: healing | Expected: life | Correct: False
#
#   Perplexity: 28684059.60
#
# ID: 54 | Category: Spells
#   Sentence: The mage conjures an [MASK] of a roaring demon to deceive enemies.
#   Predicted: image | Expected: illusion | Correct: False
#
#   Perplexity: 993627721.63
#
# ID: 55 | Category: Spells
#   Sentence: The paladin casts [MASK] of faith to protect their allies from harm.
#   Predicted: vows | Expected: shield | Correct: False
#
#   Perplexity: 53957286.89
#
# ID: 56 | Category: Spells
#   Sentence: A druid can speak with [MASK] using a simple incantation.
#   Predicted: spirits | Expected: animals | Correct: False
#
#   Perplexity: 33021070.07
#
# ID: 57 | Category: Spells
#   Sentence: The bard's song inspires [MASK] in their companions.
#   Predicted: interest | Expected: courage | Correct: False
#
#   Perplexity: 39225983.51
#
# ID: 58 | Category: Spells
#   Sentence: With a flick of her wrist, she cast the [MASK] spell as a beam of red light streaks forth.
#   Predicted: same | Expected: fireball | Correct: False
#
#   Perplexity: 236827060.16
#
# ID: 59 | Category: Spells
#   Sentence: The necromancer raises a [MASK] with a word of power.
#   Predicted: hand | Expected: skeleton | Correct: False
#
#   Perplexity: 968585310.57
#
# ID: 60 | Category: Spells
#   Sentence: The spell of invisibility renders the caster [MASK].
#   Predicted: invisible | Expected: undetectable | Correct: False
#
#   Perplexity: 21310004.06
#
# ID: 61 | Category: Rules
#   Sentence: Casting a spell is an example of an [MASK].
#   Predicted: example | Expected: action | Correct: False
#
#   Perplexity: 13973282.89
#
# ID: 62 | Category: Rules
#   Sentence: Rolling a [MASK] causes an automatic success.
#   Predicted: ball | Expected: natural 20 | Correct: False
#
#   Perplexity: 170875811.37
#
# ID: 63 | Category: Rules
#   Sentence: Players can take an [MASK], bonus action, and a reaction on their turn
#   Predicted: action | Expected: action | Correct: True
#
#   Perplexity: 17017643.21
#
# ID: 64 | Category: Rules
#   Sentence: Critical hits deal [MASK] the normal damage.
#   Predicted: double | Expected: double | Correct: True
#
#   Perplexity: 9264781.93
#
# ID: 65 | Category: Rules
#   Sentence: A failed [MASK] throw can result in the paralyzed status.
#   Predicted: free | Expected: saving | Correct: False
#
#   Perplexity: 16397359.01
#
# ID: 66 | Category: Rules
#   Sentence: An attack of opportunity occurs when an enemy [MASK].
#   Predicted: attacks | Expected: retreats | Correct: False
#
#   Perplexity: 41792972.20
#
# ID: 67 | Category: Rules
#   Sentence: Spellcasters must maintain [MASK] to keep concentration spells active.
#   Predicted: balance | Expected: focus | Correct: False
#
#   Perplexity: 993104.22
#
# ID: 68 | Category: Rules
#   Sentence: A short rest allows players to recover [MASK].
#   Predicted: points | Expected: hit points | Correct: False
#
#   Perplexity: 3517034.43
#
# ID: 69 | Category: Rules
#   Sentence: During combat, players act in order of their [MASK].
#   Predicted: actions | Expected: initiative | Correct: False
#
#   Perplexity: 20569014.30
#
# ID: 70 | Category: Rules
#   Sentence: The DM can award [MASK] for excellent roleplaying.
#   Predicted: players | Expected: inspiration | Correct: False
#
#   Perplexity: 4296128.52
#
# Accuracy: 14.29% (10/70)
# Average Perplexity: 467782879.23
# FINE TUNED:
#
# Evaluating Model: c:\code\foe_foundry\models\minilm-finetuned
#
# ID: 1 | Category: Monster
#   Sentence: The [MASK] prowled through the forest under the cover of darkness.
#   Predicted: creature | Expected: beast | Correct: True
#
#   Perplexity: 97006.98
#
# ID: 2 | Category: Monster
#   Sentence: With every swing, the giant's [MASK] echoed across the battlefield.
#   Predicted: speed | Expected: club | Correct: False
#
#   Perplexity: 100275.86
#
# ID: 3 | Category: Monster
#   Sentence: The wyvern's tail lashed out, coated in deadly [MASK].
#   Predicted: damage | Expected: venom | Correct: False
#
#   Perplexity: 161817.98
#
# ID: 4 | Category: Monster
#   Sentence: A [MASK] of goblins stormed the village, setting fire to everything in sight.
#   Predicted: monster | Expected: horde | Correct: False
#
#   Perplexity: 78470.22
#
# ID: 5 | Category: Monster
#   Sentence: Legends tell of a creature that [MASK] fire from its maw.
#   Predicted: make | Expected: breathes | Correct: False
#
#   Perplexity: 104025.57
#
# ID: 6 | Category: Monster
#   Sentence: The ancient red dragon's scales shimmered with a [MASK] glow.
#   Predicted: powerful | Expected: fiery | Correct: False
#
#   Perplexity: 111072.35
#
# ID: 7 | Category: Monster
#   Sentence: Its eyes gleamed with [MASK], promising destruction.
#   Predicted: damage | Expected: malice | Correct: False
#
#   Perplexity: 78939.11
#
# ID: 8 | Category: Monster
#   Sentence: The ogre charged forward with a deafening [MASK].
#   Predicted: light | Expected: roar | Correct: False
#
#   Perplexity: 92142.12
#
# ID: 9 | Category: Monster
#   Sentence: A cloud of chill [MASK] surrounded the banshee as it hovered above the ground.
#   Predicted: ##s | Expected: mist | Correct: False
#
#   Perplexity: 80207.61
#
# ID: 10 | Category: Monster
#   Sentence: The troll's regeneration ability allows it to heal unless exposed to [MASK].
#   Predicted: damage | Expected: fire | Correct: False
#
#   Perplexity: 81421.53
#
# ID: 11 | Category: Monster
#   Sentence: An aura of [MASK] surrounds the demon, weakening all within reach.
#   Predicted: damage | Expected: fear | Correct: False
#
#   Perplexity: 70028.01
#
# ID: 12 | Category: Monster
#   Sentence: The hydra grows two heads for every [MASK] one.
#   Predicted: within | Expected: severed | Correct: False
#
#   Perplexity: 66822.27
#
# ID: 13 | Category: Monster
#   Sentence: A dire wolf's [MASK] is powerful enough to knock down a grown man.
#   Predicted: strength | Expected: bite | Correct: False
#
#   Perplexity: 135080.00
#
# ID: 14 | Category: Monster
#   Sentence: The undead knight's blade was cursed with [MASK] magic.
#   Predicted: its | Expected: necrotic | Correct: False
#
#   Perplexity: 56847.08
#
# ID: 15 | Category: Monster
#   Sentence: A chimera's three heads grant it a [MASK] of attacks.
#   Predicted: number | Expected: variety | Correct: False
#
#   Perplexity: 101630.36
#
# ID: 16 | Category: Monster
#   Sentence: The hidden [MASK] lurked just beyond the flickering torchlight.
#   Predicted: space | Expected: shadow | Correct: False
#
#   Perplexity: 69752.07
#
# ID: 17 | Category: Monster
#   Sentence: The behir's lightning breath deals [MASK] damage in a straight line.
#   Predicted: damage | Expected: electric | Correct: False
#
#   Perplexity: 96762.04
#
# ID: 18 | Category: Monster
#   Sentence: The gelatinous cube absorbs anything that it [MASK].
#   Predicted: appear | Expected: touches | Correct: False
#
#   Perplexity: 82815.88
#
# ID: 19 | Category: Monster
#   Sentence: A vampire cannot enter a home without an invitation from a [MASK].
#   Predicted: creature | Expected: mortal | Correct: False
#
#   Perplexity: 94782.41
#
# ID: 20 | Category: Monster
#   Sentence: The harpy's song draws travelers into deadly [MASK].
#   Predicted: creatures | Expected: traps | Correct: False
#
#   Perplexity: 163481.57
#
# ID: 21 | Category: Monster
#   Sentence: When the basilisk's gaze falls upon its victim, they turn to [MASK].
#   Predicted: prey | Expected: stone | Correct: False
#
#   Perplexity: 66908.11
#
# ID: 22 | Category: Monster
#   Sentence: A lich's phylactery contains its [MASK].
#   Predicted: nature | Expected: soul | Correct: False
#
#   Perplexity: 94372.02
#
# ID: 23 | Category: Monster
#   Sentence: The dragon turtle can breathe underwater and expel a cone of [MASK].
#   Predicted: water | Expected: steam | Correct: False
#
#   Perplexity: 113654.32
#
# ID: 24 | Category: Monster
#   Sentence: The griffon can serve as a loyal [MASK] for a Paladin.
#   Predicted: creature | Expected: steed | Correct: False
#
#   Perplexity: 108049.36
#
# ID: 25 | Category: Monster
#   Sentence: A kobold's trap is more dangerous than the [MASK] itself.
#   Predicted: creature | Expected: creature | Correct: True
#
#   Perplexity: 95370.78
#
# ID: 26 | Category: Monster
#   Sentence: The minotaur guards the [MASK] deep within the labyrinth.
#   Predicted: space | Expected: treasure | Correct: False
#
#   Perplexity: 94859.19
#
# ID: 27 | Category: Monster
#   Sentence: A werewolf transforms under the [MASK] of a full moon.
#   Predicted: area | Expected: light | Correct: False
#
#   Perplexity: 158359.32
#
# ID: 28 | Category: Monster
#   Sentence: The cyclops wields a tree as if it were a [MASK].
#   Predicted: creature | Expected: club | Correct: False
#
#   Perplexity: 93506.08
#
# ID: 29 | Category: Monster
#   Sentence: A manticore can fire [MASK] from its spiked tail.
#   Predicted: it | Expected: spines | Correct: False
#
#   Perplexity: 94675.18
#
# ID: 30 | Category: Monster
#   Sentence: The massive eagle-like [MASK] spreads its wings and takes to the sky.
#   Predicted: creature | Expected: roc | Correct: False
#
#   Perplexity: 103041.36
#
# ID: 31 | Category: Monster
#   Sentence: The salamander thrives in the [MASK] of active volcanoes.
#   Predicted: space | Expected: heat | Correct: False
#
#   Perplexity: 106293.49
#
# ID: 32 | Category: Monster
#   Sentence: The banshee's wail can [MASK] the souls of the living.
#   Predicted: cast | Expected: shatter | Correct: False
#
#   Perplexity: 79184.15
#
# ID: 33 | Category: Monster
#   Sentence: A gelatinous cube's form is nearly [MASK].
#   Predicted: tiny | Expected: invisible | Correct: False
#
#   Perplexity: 129674.94
#
# ID: 34 | Category: Monster
#   Sentence: A succubus charms its victims with [MASK].
#   Predicted: damage | Expected: beauty | Correct: False
#
#   Perplexity: 62283.78
#
# ID: 35 | Category: Monster
#   Sentence: The golem follows the commands of its [MASK] without question.
#   Predicted: character | Expected: creator | Correct: False
#
#   Perplexity: 87412.13
#
# ID: 36 | Category: Monster
#   Sentence: A mimic disguises itself as mundane [MASK] to ambush prey.
#   Predicted: creatures | Expected: objects | Correct: False
#
#   Perplexity: 95554.32
#
# ID: 37 | Category: Monster
#   Sentence: The mind flayer consumes the [MASK] of its victims.
#   Predicted: damage | Expected: brains | Correct: False
#
#   Perplexity: 110612.63
#
# ID: 38 | Category: Monster
#   Sentence: The kraken's tentacles can drag entire [MASK] into the sea.
#   Predicted: creature | Expected: ships | Correct: False
#
#   Perplexity: 162639.51
#
# ID: 39 | Category: Monster
#   Sentence: A hellhound's breath smells of [MASK] sulfur.
#   Predicted: its | Expected: burning | Correct: False
#
#   Perplexity: 58708.85
#
# ID: 40 | Category: Monster
#   Sentence: The frost giant's ax is enchanted with [MASK] magic.
#   Predicted: its | Expected: ice | Correct: False
#
#   Perplexity: 59824.31
#
# ID: 41 | Category: Monster
#   Sentence: A night hag can invade dreams and spread [MASK].
#   Predicted: damage | Expected: nightmares | Correct: False
#
#   Perplexity: 87100.91
#
# ID: 42 | Category: Monster
#   Sentence: The beholder's central eye projects an anti-[MASK] cone.
#   Predicted: stealth | Expected: magic | Correct: False
#
#   Perplexity: 82910.55
#
# ID: 43 | Category: Monster
#   Sentence: The basilisk's venom causes [MASK] to spread through the veins.
#   Predicted: it | Expected: paralysis | Correct: False
#
#   Perplexity: 81573.09
#
# ID: 44 | Category: Monster
#   Sentence: The dracolich is an [MASK] dragon and a powerful spellcaster.
#   Predicted: powerful | Expected: undead | Correct: False
#
#   Perplexity: 107059.96
#
# ID: 45 | Category: Monster
#   Sentence: The djinn can grant wishes, but always with a [MASK].
#   Predicted: action | Expected: price | Correct: False
#
#   Perplexity: 64552.09
#
# ID: 46 | Category: Monster
#   Sentence: The owlbear's screech is enough to scare off most [MASK].
#   Predicted: creatures | Expected: predators | Correct: False
#
#   Perplexity: 104973.81
#
# ID: 47 | Category: Monster
#   Sentence: A fire elemental engulfs everything in [MASK].
#   Predicted: fire | Expected: flames | Correct: True
#
#   Perplexity: 78281.56
#
# ID: 48 | Category: Monster
#   Sentence: The ghost is trapped in the mortal plane by unfinished [MASK].
#   Predicted: time | Expected: business | Correct: False
#
#   Perplexity: 93810.92
#
# ID: 49 | Category: Monster
#   Sentence: A ghast's stench is so foul it causes those nearby to [MASK].
#   Predicted: survive | Expected: retreat | Correct: False
#
#   Perplexity: 82227.14
#
# ID: 50 | Category: Monster
#   Sentence: The hydra retreats only when all of its heads are [MASK].
#   Predicted: dead | Expected: destroyed | Correct: False
#
#   Perplexity: 124815.92
#
# ID: 51 | Category: Spells
#   Sentence: Casting [MASK] allows the wizard to hover for a short duration.
#   Predicted: spell | Expected: levitate | Correct: False
#
#   Perplexity: 45680.79
#
# ID: 52 | Category: Spells
#   Sentence: The sorcerer can summon a [MASK] to fight by their side.
#   Predicted: creature | Expected: familiar | Correct: False
#
#   Perplexity: 109596.62
#
# ID: 53 | Category: Spells
#   Sentence: The cleric's healing spell can restore [MASK] to the injured.
#   Predicted: damage | Expected: life | Correct: False
#
#   Perplexity: 120903.42
#
# ID: 54 | Category: Spells
#   Sentence: The mage conjures an [MASK] of a roaring demon to deceive enemies.
#   Predicted: creature | Expected: illusion | Correct: False
#
#   Perplexity: 73641.61
#
# ID: 55 | Category: Spells
#   Sentence: The paladin casts [MASK] of faith to protect their allies from harm.
#   Predicted: ability | Expected: shield | Correct: False
#
#   Perplexity: 46341.51
#
# ID: 56 | Category: Spells
#   Sentence: A druid can speak with [MASK] using a simple incantation.
#   Predicted: it | Expected: animals | Correct: False
#
#   Perplexity: 80123.36
#
# ID: 57 | Category: Spells
#   Sentence: The bard's song inspires [MASK] in their companions.
#   Predicted: ability | Expected: courage | Correct: False
#
#   Perplexity: 73598.43
#
# ID: 58 | Category: Spells
#   Sentence: With a flick of her wrist, she cast the [MASK] spell as a beam of red light streaks forth.
#   Predicted: magic | Expected: fireball | Correct: False
#
#   Perplexity: 67212.97
#
# ID: 59 | Category: Spells
#   Sentence: The necromancer raises a [MASK] with a word of power.
#   Predicted: action | Expected: skeleton | Correct: False
#
#   Perplexity: 127326.26
#
# ID: 60 | Category: Spells
#   Sentence: The spell of invisibility renders the caster [MASK].
#   Predicted: prey | Expected: undetectable | Correct: False
#
#   Perplexity: 76134.75
#
# ID: 61 | Category: Rules
#   Sentence: Casting a spell is an example of an [MASK].
#   Predicted: spell | Expected: action | Correct: False
#
#   Perplexity: 64413.48
#
# ID: 62 | Category: Rules
#   Sentence: Rolling a [MASK] causes an automatic success.
#   Predicted: action | Expected: natural 20 | Correct: False
#
#   Perplexity: 63607.08
#
# ID: 63 | Category: Rules
#   Sentence: Players can take an [MASK], bonus action, and a reaction on their turn
#   Predicted: action | Expected: action | Correct: True
#
#   Perplexity: 116714.74
#
# ID: 64 | Category: Rules
#   Sentence: Critical hits deal [MASK] the normal damage.
#   Predicted: to | Expected: double | Correct: False
#
#   Perplexity: 133537.21
#
# ID: 65 | Category: Rules
#   Sentence: A failed [MASK] throw can result in the paralyzed status.
#   Predicted: saving | Expected: saving | Correct: True
#
#   Perplexity: 101219.08
#
# ID: 66 | Category: Rules
#   Sentence: An attack of opportunity occurs when an enemy [MASK].
#   Predicted: dies | Expected: retreats | Correct: False
#
#   Perplexity: 158370.65
#
# ID: 67 | Category: Rules
#   Sentence: Spellcasters must maintain [MASK] to keep concentration spells active.
#   Predicted: ability | Expected: focus | Correct: False
#
#   Perplexity: 98791.68
#
# ID: 68 | Category: Rules
#   Sentence: A short rest allows players to recover [MASK].
#   Predicted: it | Expected: hit points | Correct: False
#
#   Perplexity: 92629.44
#
# ID: 69 | Category: Rules
#   Sentence: During combat, players act in order of their [MASK].
#   Predicted: action | Expected: initiative | Correct: False
#
#   Perplexity: 93594.85
#
# ID: 70 | Category: Rules
#   Sentence: The DM can award [MASK] for excellent roleplaying.
#   Predicted: it | Expected: inspiration | Correct: False
#
#   Perplexity: 73350.59
#
# Accuracy: 7.14% (5/70)
# Average Perplexity: 94606.56
